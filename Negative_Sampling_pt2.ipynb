# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# your model focuses on during captioning
import matplotlib.pyplot as plt

import collections
import random
import numpy as np
import os
import time
import json
from PIL import Image

# %%
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  print('hi')
  annotation_zip = tf.keras.utils.get_file('captions.zip',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                           extract=True)
  annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
  os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('train2014.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='http://images.cocodataset.org/zips/train2014.zip',
                                      extract=True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder
# Out:
# hi
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 4s 0us/step
# 252887040/252872794 [==============================] - 4s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
#  8527101952/13510573713 [=================>............] - ETA: 1:27

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 30,000 examples.
train_image_paths = image_paths[:6000]
print(len(train_image_paths))
# Out:
# 6000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A man holding a hot dog in both of his hands. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F6769609D90>

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.keras.layers.Resizing(299, 299)(img)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
from tqdm import tqdm

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in tqdm(image_dataset):
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())
# Out:
#  88%|████████▊ | 331/375 [22:59<03:16,  4.46s/it]

# %%
caption_dataset = tf.data.Dataset.from_tensor_slices(train_captions)
def standardize(inputs):
  inputs = tf.strings.lower(inputs)
  return tf.strings.regex_replace(inputs,
                                  r"!\"#$%&\(\)\*\+.,-/:;=?@\[\\\]^_`{|}~", "")

# Max word count for a caption.
max_length = 50
# Use the top 5000 words for a vocabulary.
vocabulary_size = 5000
tokenizer = tf.keras.layers.TextVectorization(
    max_tokens=vocabulary_size,
    standardize=standardize,
    output_sequence_length=max_length)
# Learn the vocabulary from the caption data.
tokenizer.adapt(caption_dataset)

# %%
cap_vector = caption_dataset.map(lambda x: tokenizer(x))

# %%
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

# %%
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int64]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 64, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 64, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 64, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
    x = self.fc2(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, tokenizer.vocabulary_size())

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0

  # initializing the hidden state for each batch
  # because the captions are not related from image to image
  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([word_to_index('<start>')] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
EPOCHS = 7

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 1.9288
# Epoch 1 Batch 100 Loss 1.1061
# Epoch 1 Batch 200 Loss 1.0085
# Epoch 1 Batch 300 Loss 0.9023
# Epoch 1 Loss 1.045406
# Time taken for 1 epoch 2520.79 sec
#
# Epoch 2 Batch 0 Loss 0.8370
# Epoch 2 Batch 100 Loss 0.8480
# Epoch 2 Batch 200 Loss 0.7144
# Epoch 2 Batch 300 Loss 0.7365
# Epoch 2 Loss 0.786697
# Time taken for 1 epoch 2421.93 sec
#
# Epoch 3 Batch 0 Loss 0.7246
# Epoch 3 Batch 100 Loss 0.6712
# Epoch 3 Batch 200 Loss 0.6951
# Epoch 3 Batch 300 Loss 0.6869
# Epoch 3 Loss 0.706386
# Time taken for 1 epoch 2348.71 sec
#
# Epoch 4 Batch 0 Loss 0.6434
# Epoch 4 Batch 100 Loss 0.6742
# Epoch 4 Batch 200 Loss 0.6599
# Epoch 4 Batch 300 Loss 0.6201
# Epoch 4 Loss 0.654577
# Time taken for 1 epoch 2327.99 sec
#
# Epoch 5 Batch 0 Loss 0.6077
# Epoch 5 Batch 100 Loss 0.6345
# Epoch 5 Batch 200 Loss 0.5900
# Epoch 5 Batch 300 Loss 0.5972
# Epoch 5 Loss 0.615821
# Time taken for 1 epoch 2326.47 sec
#
# Epoch 6 Batch 0 Loss 0.6121
# Epoch 6 Batch 100 Loss 0.5778
# Epoch 6 Batch 200 Loss 0.6211
# Epoch 6 Batch 300 Loss 0.5878
# Epoch 6 Loss 0.580800
# Time taken for 1 epoch 2516.68 sec
#
# Epoch 7 Batch 0 Loss 0.6255
# Epoch 7 Batch 100 Loss 0.5487
# Epoch 7 Batch 200 Loss 0.4954

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([word_to_index('<start>')], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        predicted_word = tf.compat.as_text(index_to_word(predicted_id).numpy())
        result.append(predicted_word)

        if predicted_word == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(int(np.ceil(len_result/2)), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                         for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a museum [UNK] of old cell phones in a long glass case. <end>
# Prediction Caption: a group of people and electronic luggage carousel up. <end>

# %%
import glob
#image_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ab/TensorFlow_logo.svg/1200px-TensorFlow_logo.svg.png'
#image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)
#print(image_path)
path = '/content/drive/MyDrive/meme_df/meme-generator-dataset/memegenimages/'
for filename in glob.glob(os.path.join(path, '*.jpg')):
   with open(os.path.join(os.getcwd(), filename), 'r') as f:
       result, attention_plot = evaluate(os.path.join(os.getcwd(), filename))
       print(filename[-12:]+': ' , ' '.join(result))
#plot_attention(image_path, result, attention_plot)
# opening the image
#Image.open(image_path)
# Out:
# 10409553.jpg:  a close up of a man and a [UNK] each other. <end>
# 10414701.jpg:  a dark style women sitting down <end>
# 10415609.jpg:  a man with a bunch of a drink in a high tile. <end>
# 10415969.jpg:  the old is on computer jacket, building. <end>
# 10416628.jpg:  a group of groups of people are all mounted to an audience dye wine. <end>
# 10416742.jpg:  a person flying a very [UNK] by a yellow flowers. <end>
# 10417909.jpg:  a set of an unique [UNK] signs in his racket at his ear of an air <end>
# 10418515.jpg:  a rusted drinking a bag of a cup of drink covered in a wicker [UNK] <end>
# 10418571.jpg:  a picture of [UNK] in a head and a small right costume and as if a [UNK] <end>
# 10420893.jpg:  a closeup of a collage of a man [UNK] inside of his neck. <end>
# 10422461.jpg:  a person in this [UNK] <end>
# 10423919.jpg:  a [UNK] [UNK] in a basket of a shop <end>
# 10428139.jpg:  there are two women in a glass. <end>
# 10431468.jpg:  a man in a courtyard of a microphone. <end>
# 10438018.jpg:  a black and a woman holding a cellphone controller. <end>
# 10438085.jpg:  a male with an [UNK] underneath a glass he stance with cell phone in facing each other. <end>
# 10441924.jpg:  the smiling man talking with a top <end>
# 10442462.jpg:  a box of an ear where a beer <end>
# 10442561.jpg:  a pretty people sitting by a zoo. <end>
# 10442582.jpg:  a man holds up near his hands. <end>
# 10442587.jpg:  a man eating a tie listening <end>
# 10442608.jpg:  a man stands in front of their purse. <end>
# 10443213.jpg:  a photo of a man with a jump with two different [UNK] left [UNK] <end>
# 10444285.jpg:  a close up of a toddler with a glass of the roses in a dark chair holding onto a [UNK] look. <end>
# 10444366.jpg:  a bunch of people are looking into a room. <end>
# 10444401.jpg:  a cat sitting around in a wrapper. <end>
# 10446835.jpg:  a collage of a [UNK] reflection of a blonde hair with glasses next to her. <end>
# 10447577.jpg:  there is a glass of a [UNK] glass. <end>
# 10457222.jpg:  a woman with a [UNK] most of a microphone. <end>
# 10458150.jpg:  a bunch of a cyclist on a person. <end>
# 10459219.jpg:  a and a little arm [UNK] in a [UNK] <end>
# 10460273.jpg:  two sheep are standing on with a lasso going down eating together <end>
# 10460799.jpg:  an old pack of an image struggles to his neck. <end>
# 10461262.jpg:  a man with a camera at drinks a [UNK] next to a microphone. <end>
# 10462318.jpg:  a man pours drinks and office book glass. <end>
# 10468056.jpg:  a picture of people sitting next to eggs <end>
# 10469414.jpg:  a woman is over a dog on a basket <end>
# 10470553.jpg:  a brown cat and a [UNK] into a basket <end>
# 10474098.jpg:  a selfie of a <end>
# 10474451.jpg:  a bunch of a [UNK] decorated baseball cup, blue [UNK] with some plastic shapes of a small baskets and a shorts with its [UNK] <end>
# 10475177.jpg:  a boy in a large painted black and a book shelf outside of a train <end>
# 10477345.jpg:  there are many people standing in the wilderness. <end>
# 10479990.jpg:  a very big brown dog is shown who is hanging around underneath a small bell on the learning to eat a glass [UNK] bananas. <end>
# 10480083.jpg:  the small front [UNK] a red paneling are outside with a blue [UNK] through some chairs <end>
# 10480534.jpg:  a man hangs by a [UNK] with a [UNK] [UNK] <end>
# 10480535.jpg:  a man and a [UNK] [UNK] <end>
# 10481536.jpg:  a skull colored fruit. <end>
# 10481574.jpg:  a dog standing next to a dog <end>
# 10481647.jpg:  a small bird on a block of other near a pair of broccoli and one with supplies. <end>
# 10481731.jpg:  a herd of a couple of a big, bird and a trees. <end>
# 10482134.jpg:  a furry sheep in a large dog and wearing a dog with trees next to a life inside a plaid puppy rides in a store. <end>
# 10482354.jpg:  grey dog watches taped to an ocean with a dog as a dog sitting on a basket with a pretty dog enjoying it sits on a man shoes with birds of people. <end>
# 10484050.jpg:  a barn. <end>
# 10485412.jpg:  a woman is standing by the other in a pink dress woman's chest. <end>
# 10486419.jpg:  a couple of a groom displayed for a sauces and a bunch of an ear tan and two plates of a picture <end>
# 10492246.jpg:  one white [UNK] angle with a catchers polish near. <end>
# 10493396.jpg:  two women pose for dogs. <end>
# 10494149.jpg:  a brown and white suitcase <end>
# 10494571.jpg:  a closeup view of a large [UNK] colorful laces on a [UNK] car. <end>
# 10494874.jpg:  a [UNK] long head standing in a red tops, in a display <end>
# 10495012.jpg:  a sun is standing next to a gas mask. <end>
# 10495545.jpg:  a collage of a man is standing in a shelf. <end>
# 10502300.jpg:  a white cabinet of an electric paint in a suit <end>
# 10505306.jpg:  a man takes a red hat sitting in front of a office. <end>
# 10508434.jpg:  a close up of a kitchen filled with a hat leans to a basket <end>
# 10508485.jpg:  a peers sticking though the zoo. <end>
# 10508634.jpg:  a photo of a [UNK] of staples of a closeup of soup sitting next to a [UNK] berries <end>
# 10508656.jpg:  a white and white photo of a glass close up next to a coffee tea pot in the grill. <end>
# 10508794.jpg:  a small beard and a [UNK] to see the camera <end>
# 10508848.jpg:  a fit next to a stone wall. <end>
# 10508884.jpg:  a closeup of a glass vase is sitting next to a purse <end>
# 10508968.jpg:  a blender and a store close to a beer sitting next to a stone wall. <end>
# 10509083.jpg:  a [UNK] dressed in an display against a museum. <end>
# 10509827.jpg:  the contents the ears witting up crate and rocks juice casual [UNK] <end>
# 10510070.jpg:  a painting of hats are next to a stone wall. <end>
# 10510586.jpg:  a man is giving a [UNK] his face. <end>
# 10510850.jpg:  a book in the mirror as us a fan and some buildings <end>
# 10514625.jpg:  a old gentleman with a the [UNK] on adjusting a [UNK] teeth. <end>
# 10515180.jpg:  a [UNK] in a [UNK] in a shed <end>
# 10515638.jpg:  a truck with a man is being driven by side. <end>
# 10515701.jpg:  a truck with a car show tow truck <end>
# 10517392.jpg:  a [UNK] looking at the end of a basket <end>
# 10517861.jpg:  a cut urinals at a long tie stands by a glass in the simple window. <end>
# 10518720.jpg:  a couple in a blow showcasing different [UNK] and aiming for benches, a sky background <end>
# 10527196.jpg:  a display case decorated with blue [UNK] in a tomato <end>
# 10527611.jpg:  a man in large neck [UNK] while dressed a victory [UNK] <end>
# 10531814.jpg:  a man in a bear <end>
# 10532003.jpg:  a man smiling bananas. <end>
# 10534952.jpg:  a building with multiple trucks on their display. <end>
# 10535085.jpg:  a truck sits on it. <end>
# 10536067.jpg:  the adult and a very [UNK] are [UNK] with head next to a large [UNK] and water <end>
# 10536111.jpg:  a wine with a [UNK] and a sign next to a giant thrown from its head up with three purse behind a pink tree. <end>
# 10538096.jpg:  there is a rusted two graffiti machine <end>
# 10538130.jpg:  a couple of a truck with a truck on its trailer. <end>
# 10538385.jpg:  a [UNK] in a basket. <end>
# 10539669.jpg:  a guy who is posing. <end>
# 10540155.jpg:  a bird is eating a dog and a dog in this drawer <end>
# 10540764.jpg:  a [UNK] with the clock displayed in a white room. <end>
# 10542307.jpg:  multiple other women pose beside each other. <end>
# 10543833.jpg:  a man that are with a [UNK] a [UNK] and looking on. <end>
# 10544494.jpg:  a couple of well filled with a bunch of a display close up a variety of three different teams of bears are sitting next to two figures together <end>
# 10545680.jpg:  a young man with a picture of a cell phone. <end>
# 10549483.jpg:  a couple of people are sitting on top of a skull next to a shapes drinks by a smaller [UNK] with an [UNK] and vegetables and [UNK] <end>
# 10552656.jpg:  a woman that is not dressed up against a counter. <end>
# 10555892.jpg:  a collage of a man sitting next to [UNK] <end>
# 10556866.jpg:  a black and white and white photo from all a large, of hard blue sky. <end>
# 10557603.jpg:  a dog in a cardboard table <end>
# 10558054.jpg:  an [UNK] girl are posing in the midst of a tablet <end>
# 10560627.jpg:  a collage of people who are inside of a picture. <end>
# 10560927.jpg:  a person hold something <end>
# 10560930.jpg:  the tongue next to a skull and standing on a black trays. <end>
# 10560951.jpg:  a collage of three pictures of beer. <end>
# 10561784.jpg:  a [UNK] [UNK] with alot of various signs <end>
# 10561953.jpg:  a checks milk [UNK] in a door of fruit outside. <end>
# 10562944.jpg:  a brown shapes photo that is singing into the woods. <end>
# 10563310.jpg:  a [UNK] [UNK] [UNK] [UNK] cabinets <end>
# 10563330.jpg:  a close up a man is wearing a plaid shirt and a [UNK] <end>
# 10563722.jpg:  a [UNK] two everything in a big [UNK] <end>
# 10564248.jpg:  a dog is standing on a chair in a barbed wire hanging into the operating with its legs attached to a dog in a parade with its [UNK] and standing by <end>
# 10564524.jpg:  a collage of a [UNK] <end>
# 10566635.jpg:  two police phones and several [UNK] <end>
# 10568370.jpg:  a cat sits on a green cushion of it <end>
# 10568852.jpg:  a front of a the sun waits to the time of tables with a [UNK] <end>
# 10578563.jpg:  a dog that is resting between an open background sitting atop a pool. <end>
# 10579576.jpg:  a close up a black [UNK] sings for a neck tie next to a suit player. <end>
# 10580176.jpg:  a truck with a dog pad and a blue dog that is eating an electronic truck drives in front of a pen next to a case while behind a car. <end>
# 10580219.jpg:  a dog sitting on it's back. <end>
# 10582786.jpg:  an image of people are attached to shear a japanese electronic [UNK] a crowd of a tomato pawn shop. <end>
# 10584189.jpg:  a kitten standing inside of a short day. <end>
# 10584214.jpg:  a grey and white cat sitting down looking direction. <end>
# 10586188.jpg:  one is a water [UNK] and one of land wearing one still water while playing in the air in the middle of a very fancy counters. <end>
# 10586406.jpg:  a couple of beer and a next to each other. <end>
# 10587367.jpg:  a contents of [UNK] [UNK] <end>
# 10588859.jpg:  a man holding a [UNK] [UNK] <end>
# 10588993.jpg:  a well asian counter covered banquet [UNK] sunglasses, and a pink wall. <end>
# 10593218.jpg:  a wine face at the wall. <end>
# 10593223.jpg:  man photo's of a man in a [UNK] <end>
# 10594869.jpg:  a cool space [UNK] in a [UNK] <end>
# 10594946.jpg:  a person is checking his hand looks at a bench eating. <end>
# 10595964.jpg:  a couple of three different bags. <end>
# 10597144.jpg:  a man hold a book <end>
# 10597652.jpg:  a close of a white and white vase with a [UNK] a [UNK] across a table <end>
# 10597757.jpg:  a shirtless girl climbing a suit, dress operating [UNK] [UNK] <end>
# 10598956.jpg:  a man holding a [UNK] in a [UNK] while another man in front of a shelf with tie and is leaning rock book shelves <end>
# 10599830.jpg:  a teenager mounted to the microphone and a tennis <end>
# 10599997.jpg:  a woman dressed in dress pours him <end>
# 10602375.jpg:  a man with a suit, [UNK] <end>
# 10604271.jpg:  a woman have lots of a hot dog and a trash cases <end>
# 10604712.jpg:  a collage of three people sitting with two containers behind each other. <end>
# 10605091.jpg:  this is standing in his reflection of clothes. <end>
# 10606336.jpg:  a person with a [UNK] in a counter. <end>
# 10610524.jpg:  a table attached. <end>
# 10614191.jpg:  a lady dressed in a wall. <end>
# 10615304.jpg:  a male a person holding a not it <end>
# 10615966.jpg:  a [UNK] with plastic tuxedo and various [UNK] are both all dressed in a gear [UNK] with a smaller entire row and a smaller animal. <end>
# 10619057.jpg:  a man with a bear. <end>
# 10619487.jpg:  a man sitting with a red office bench a sweater. <end>
# 10620844.jpg:  a collage of a collage of a glass [UNK] a doughnut <end>
# 10621569.jpg:  a man stands on his couch holding up by a message on the bench. <end>
# 10623091.jpg:  a man with a sky in large blue background. <end>
# 10625348.jpg:  a mans hands giving a mans ear of them and a microphone pieces of s lady holds onto a pink dress fixes a tie posing for a microphone. <end>
# 10625493.jpg:  a young child a book [UNK] to see his head by the ocean in the background. <end>
# 10625986.jpg:  some people, [UNK] covered lift. <end>
# 10626057.jpg:  a man is looking game glasses and a [UNK] costume along a [UNK] <end>
# 10628214.jpg:  a man with a long [UNK] a long fish and a [UNK] [UNK] and a book <end>
# 10628336.jpg:  a woman sits showing the top of a desk beside a [UNK] picture <end>
# 10628698.jpg:  a [UNK] each other. <end>
# 10629264.jpg:  a victory is displayed. <end>
# 10629266.jpg:  a [UNK] is a large cat are on top of a fast <end>
# 10629308.jpg:  a purse looks like the top of a miniature resting on it. <end>
# 10631489.jpg:  two speakers. show covered in the air in an antique house. <end>
# 10635145.jpg:  an old fire repair level view of electronics that has been enjoys a messy site. <end>
# 10640571.jpg:  a conductor and glasses on a table. <end>
# 10641430.jpg:  a woman with his phones in the bathroom. <end>
# 10643929.jpg:  a train is has various things on the brush a red tropical other. <end>
# 10647635.jpg:  a stop [UNK] in a building. <end>
# 10648781.jpg:  a black and white colored airplane in midair near each other in the background. <end>
# 10649615.jpg:  a woman is lit book on a train. <end>
# 10649893.jpg:  a man and a man and blue and white photo of women are looking at a man. <end>
# 10651154.jpg:  a man with a skull to see a [UNK] the camera. <end>
# 10651164.jpg:  a selfie of wine in a room. <end>
# 10652756.jpg:  a man [UNK] a bowler sunglasses, an american one photo of a suit tank top samples a book case. <end>
# 10653080.jpg:  a picture of a [UNK] is sitting in two smaller home plate next to each other. <end>
# 10654033.jpg:  a cafeteria inside and a tie <end>
# 10659403.jpg:  several pictures of a man with uniform juice tie. <end>
# 10661093.jpg:  a couple photo of three brushes treats. <end>
# 10662297.jpg:  a [UNK] view of a grassy grazes in a napkin under a stream. <end>
# 10662449.jpg:  a man in a red tie. <end>
# 10662651.jpg:  a male man wearing a long tie and tie eats a gray suit, dress [UNK] <end>
# 10666087.jpg:  two very cute cow stand in a dark [UNK] hat while leaning against a fence. <end>
# 10666788.jpg:  a woman stands and a plaid shirt and one on a room with his neck. [UNK] [UNK] by a pony with a book cases. <end>
# 10666805.jpg:  a view of a large brown basket of a few cases shows a dog in suits are <end>
# 10667832.jpg:  a couple taking photos on. <end>
# 10671239.jpg:  a man in black fur in front of a [UNK] one of an entertainment [UNK] <end>
# 10671631.jpg:  a man setting from a high frame. <end>
# 10674629.jpg:  a small young child in his mouth. <end>
# 10676617.jpg:  a woman sitting in a crowded bench. <end>
# 10678811.jpg:  an airport sign sticking into his bag. <end>
# 10679210.jpg:  a man with a bow and wearing ties are standing next to each other. <end>
# 10680056.jpg:  a [UNK] a closeup the union [UNK] <end>
# 10688360.jpg:  a young lady making a [UNK] his rifle. <end>
# 10689317.jpg:  a [UNK] a man surrounded by a microphone. <end>
# 10689388.jpg:  a man standing in the wild. <end>
# 10689789.jpg:  a close up a pair of it looking background <end>
# 10690623.jpg:  a man in a brown suit, vest and man with a [UNK] giving a high up against a smaller tops, <end>
# 10691195.jpg:  a smiling police store with a dinosaur <end>
# 10691324.jpg:  a large bird with a dog being feet. <end>
# 10692727.jpg:  a picture of an asian groom and pictures <end>
# 10694346.jpg:  a blurry photo of himself in a [UNK] <end>
# 10694462.jpg:  the [UNK] out of us be near a green [UNK] <end>
# 10694752.jpg:  a collage of a [UNK] holding a shapes and a [UNK] <end>
# 10698678.jpg:  a boys sitting on a concrete garden. <end>
# 10701149.jpg:  a chair of wine plants <end>
# 10701788.jpg:  a zoo old [UNK] of a dress standing behind another couple people looking [UNK] state of each other on the side by an open tie <end>
# 10704555.jpg:  a picture of a tennis rackets. <end>
# 10705822.jpg:  a large very large body of goats walking through a long grassy area near a custard mountain of tall grassy weather. <end>
# 10706845.jpg:  a man in a chair with a mug in a door of a suit and an apron while four kind of a [UNK] <end>
# 10707179.jpg:  multiple men standing next to a picture. <end>
# 10707185.jpg:  a man sitting next to a cobblestone area. <end>
# 10707213.jpg:  some pictures of man wearing a boy. <end>
# 10707501.jpg:  a pair of a dog and other things in a [UNK] <end>
# 10707541.jpg:  a man that is wearing a glow in a building. <end>
# 10712658.jpg:  a man on an umbrella. <end>
# 10714806.jpg:  a man that has different [UNK] a drink in an [UNK] <end>
# 10714882.jpg:  young man standing by building. <end>
# 10717170.jpg:  a local display case with shiny white photo of a tennis has a large shapes and a [UNK] <end>
# 10720599.jpg:  a large brown sits with a glass case. <end>
# 10721779.jpg:  a man wearing a white suit, tie and a [UNK] [UNK] <end>
# 10722104.jpg:  there is an [UNK] bright blue fire drawer <end>
# 10728555.jpg:  a close up of a young child with a fish too <end>
# 10729959.jpg:  a woman wearing glasses and a basket of a person stands around a tie <end>
# 10730087.jpg:  a black and white photo of a left front of a wall <end>
# 10731300.jpg:  a [UNK] women standing in the background. <end>
# 10732024.jpg:  a beard and a dog sticking it's contents dressed up a [UNK] sitting under a basket with their ears [UNK] <end>
# 10734345.jpg:  man that is skiing in a field and a park <end>
# 10736584.jpg:  a large brown dog sitting in their teeth. <end>
# 10737378.jpg:  a woman an image of furniture on. <end>
# 10744544.jpg:  a man with three pictures. <end>
# 10748317.jpg:  a man walking in his hands. <end>
# 10749069.jpg:  this man with a picture. <end>
# 10754298.jpg:  a man with a man. <end>
# 10754400.jpg:  a very little girl on a cage. <end>
# 10756491.jpg:  a man holding a coffee cup. <end>
# 10758906.jpg:  this is in a museum tops. <end>
# 10759879.jpg:  a [UNK] and both [UNK] out another man on it <end>
# 10761830.jpg:  a large decorated with wedding dresses and a display up of [UNK] and one stands kite in a basket. <end>
# 10763951.jpg:  a [UNK] in a basket and next to an tomato. <end>
# 10764641.jpg:  a birthday bird opened camera on a distance. <end>
# 10765011.jpg:  a pretty beautiful women in the background. <end>
# 10765517.jpg:  a man bending up to his thumb posing. <end>
# 10765577.jpg:  a man at a [UNK] <end>
# 10765864.jpg:  a collage of a collage of a woman behind a [UNK] [UNK] and a neck. a uniform and a bow pictures in a middle of a coffee <end>
# 10767770.jpg:  a close up of a [UNK] with a drink and a purse next to two different directions. <end>
# 10773223.jpg:  a toddler in a white chair. <end>
# 10774198.jpg:  a old photo of various hats <end>
# 10775815.jpg:  a collage of people with the side displayed neatly hanging vegetarian <end>
# 10777499.jpg:  an old series of a couple of a woman's handheld [UNK] microphone and ties nose and a pans next to a items beside each other. <end>
# 10777535.jpg:  a woman in a chair. <end>
# 10779303.jpg:  a [UNK] statue juggling high rise <end>
# 10779304.jpg:  a collage of a small man this [UNK] a [UNK] <end>
# 10779543.jpg:  a boy holding a chain link teeth. <end>
# 10781114.jpg:  a long large decorated with an assortment of many different color [UNK] [UNK] in the whole plastic raising their electronics <end>
# 10784747.jpg:  a picture of a dog are playing in an outdoor object. <end>
# 10784753.jpg:  a white bird is pictured with a green grass. <end>
# 10784884.jpg:  a [UNK] photo <end>
# 10785017.jpg:  a cat looking over himself in the front. <end>
# 10786481.jpg:  a wooden cup of a [UNK] <end>
# 10787031.jpg:  a black and white horse with a [UNK] towards the distance with a sunset held in a [UNK] <end>
# 10790197.jpg:  a [UNK] [UNK] office by a coats <end>
# 10793131.jpg:  hats and a camera <end>
# 10794411.jpg:  two four different [UNK] <end>
# 10794834.jpg:  a mother that is looking into white dress clothes with a hat. <end>
# 10797652.jpg:  a close up ofa a close up of the flowers, and glasses can eats his ears of her face next to the camera. <end>
# 10800808.jpg:  a close up a corner with a camera. <end>
# 10802733.jpg:  a young man wearing a oval the camera covered clothing in uniform posing for his tie with a raquet stands behind himself beside his microphone. <end>
# 10806570.jpg:  a little girl wearing a [UNK] board with his neck. <end>
# 10808697.jpg:  a man with a black vest and a tie and two pictures speaking a [UNK] <end>
# 10810344.jpg:  a man wearing a shirt with a glove and a pair of the state of a bar as a museum [UNK] <end>
# 10810631.jpg:  a display of bison has an [UNK] home tops, a display against a crowd. <end>
# 10812550.jpg:  man of ties <end>
# 10812725.jpg:  a type of a [UNK] [UNK] [UNK] in a healthy lens <end>
# 10814248.jpg:  group of a very cute close up in a picture against each [UNK] and a big cream tank in the background. <end>
# 10814332.jpg:  a male in a mother cabinets and a tie sitting in a mound of the room. <end>
# 10814348.jpg:  a big white and an office with a tie of a [UNK] <end>
# 10814367.jpg:  the older man in a [UNK] <end>
# 10819072.jpg:  a man in a necktie. <end>
# 10819250.jpg:  a white dog has a child in a pitch. <end>
# 10819415.jpg:  a close up a group of a couple of people that are carry chairs in the air for the dirt. <end>
# 10820934.jpg:  bottles drinks in uniform <end>
# 10828403.jpg:  a door showing of a skull <end>
# 10835314.jpg:  various [UNK] [UNK] and three other's u [UNK] <end>
# 10840833.jpg:  a man sitting in a clothes on his dugout <end>
# 10842087.jpg:  the male in a [UNK] at the home with a another yellow glasses and a [UNK] with a [UNK] teen in the living room <end>
# 10846105.jpg:  a couple of a woman in a bedroom. <end>
# 10853039.jpg:  a large truck is knocked out. <end>
# 10855318.jpg:  a cup of a deep water holding a man in a stick in an old fashioned [UNK] from an all green flowers displayed in a [UNK] <end>
# 10855922.jpg:  an older lady [UNK] an [UNK] <end>
# 10856313.jpg:  an <end>
# 10863925.jpg:  a man is made of a tank in a clothing in front of a picture with a tie and a [UNK] <end>
# 10864097.jpg:  a man wearing a [UNK] a [UNK] <end>
# 10867712.jpg:  a woman with banana in the background. <end>
# 10867780.jpg:  a dog stands in a wall while a dog in a white stump outside <end>
# 10868690.jpg:  a counter in a zoo exhibit. <end>
# 10869212.jpg:  a man looking at a podium with a newspaper while another man skateboarding about a microphone. <end>
# 10869390.jpg:  a couple of women standing and a stands up by an apple is standing in a line of a clock. <end>
# 10870303.jpg:  a bunch of multi colored sale with many different umbrellas are shown having a [UNK] in a painting of people. <end>
# 10873423.jpg:  sheep at night. <end>
# 10875261.jpg:  a large, dog standing beside each other wearing a bear. <end>
# 10875338.jpg:  a man eating a business something. <end>
# 10875852.jpg:  a couple in a lecture as glowing [UNK] off. <end>
# 10875878.jpg:  the president sitting at night <end>
# 10875909.jpg:  a man are watching a sign as dressed at the same [UNK] by wires giving a glass above each other. <end>
# 10875924.jpg:  a men are talking behind wine [UNK] around a table with a home. <end>
# 10878395.jpg:  a black and a couple of a big tie at a home [UNK] <end>
# 10881488.jpg:  a man with two men behind a picture. <end>
# 10881970.jpg:  a two long glass picture of clay are displayed against a white pillow. <end>
# 10882700.jpg:  an image of tall sheep standing next to each other. <end>
# 10882826.jpg:  a close over a lamb in the other by a wire feeder. <end>
# 10883030.jpg:  a sheep standing next to an enclosed area <end>
# 10883142.jpg:  an old rusted in a [UNK] in a room. <end>
# 10883707.jpg:  an entertainment road, off on display a tree stump <end>
# 10885375.jpg:  a display [UNK] some green and three different [UNK] <end>
# 10892826.jpg:  three different [UNK] another desserts containing two different kind of animals and one on a table. <end>
# 10893005.jpg:  the view of a [UNK] wheels. <end>
# 10894098.jpg:  a man standing on it <end>
# 10897635.jpg:  a man pointing to the other man and a tuxedo and a [UNK] using video game of a wine to hold a museum <end>
# 10899034.jpg:  a black and white colored hair characters fixes a microphone. <end>
# 10899517.jpg:  a [UNK] contains [UNK] produce displayed revealing from the wicker table <end>
# 10901839.jpg:  two men sitting next to each other <end>
# 10903881.jpg:  a tan and brown and white bird is staring at a cup tied into an open clothes and a skull in what there are a ears looking at an assortment of them hanging into a basket while at a blocked from its face. <end>
# 10904433.jpg:  the man looking into a suit sits next to an iron frame in a bowl. <end>
# 10904539.jpg:  a collage of a man with a foreign beer <end>
# 10908303.jpg:  a big brown trunk with a phone on the [UNK] <end>
# 10908969.jpg:  a woman that is posing for st. top of a museum [UNK] <end>
# 10909752.jpg:  a seagull standing near a rock <end>
# 10910100.jpg:  a large broccoli and a large rock in the home [UNK] <end>
# 10910904.jpg:  a tall wooden sun show in area. <end>
# 10915970.jpg:  a big [UNK] wine while a person using a luggage that includes a [UNK] [UNK] the door with lots of people. <end>
# 10918004.jpg:  man posing close by all cups and a tie and a hat bath rectangular tie and one using the ice clothing and a rider making a cup <end>
# 10918941.jpg:  a man holding up a desk. <end>
# 10919734.jpg:  a view of [UNK] [UNK] surrounded by fallen by. <end>
# 10923072.jpg:  the picture of a very cute two cups of person wearing a decorative [UNK] in a picture. <end>
# 10928935.jpg:  two photographs of a [UNK] in black suit. <end>
# 10931975.jpg:  the blurry photo of a boy dinner with a [UNK] in a classroom [UNK] [UNK] <end>
# 10933922.jpg:  a young boy brushing short couch. <end>
# 10936345.jpg:  a large glass vases are well plugged to [UNK] arranged near multiple different [UNK] <end>
# 10937382.jpg:  a bride and a camera signal. <end>
# 10938503.jpg:  a close up of drink cup beside a basket in a metal glass. <end>
# 10938701.jpg:  a old [UNK] with a [UNK] one foot streetlamp <end>
# 10938764.jpg:  a close of colored liquid stands beside a glass window. <end>
# 10938796.jpg:  a old person is about to take up very [UNK] <end>
# 10938803.jpg:  a dog resting its dog in a high room. <end>
# 10939644.jpg:  a young man in a [UNK] to a picture. <end>
# 10940705.jpg:  a collage of a [UNK] using a cat [UNK] <end>
# 10940809.jpg:  a man is holding their boots by a microphone. <end>
# 10946183.jpg:  a man standing up while as a red [UNK] [UNK] tuxedo on. <end>
# 10950125.jpg:  a man with a camera. <end>
# 10950268.jpg:  two asian man in his on a silver tray. <end>
# 10955233.jpg:  a kid in large [UNK] his teeth <end>
# 10956095.jpg:  a decorated with an uncovered which with some kind of food tables surrounded near. <end>
# 10959956.jpg:  the old two people in black and toothbrush. <end>
# 10963987.jpg:  a man with a [UNK] laid out. <end>
# 10969618.jpg:  a close up of pictures of a close up in a tie. <end>
# 10972240.jpg:  a collage of a bottle of a little well opened style bottle of a long [UNK] in a silver room [UNK] <end>
# 10972575.jpg:  a big [UNK] and a large only all a pizza amongst a [UNK] with a [UNK] <end>
# 10974689.jpg:  a portrait with a camera <end>
# 10975386.jpg:  a man [UNK] [UNK] in a [UNK] <end>
# 10986750.jpg:  a male man looking in a [UNK] <end>
# 10987331.jpg:  a lone cat [UNK] light milk are underneath a drink while their drink at an outdoor setting. <end>
# 10990453.jpg:  a wet dog standing next to each other. <end>
# 10994189.jpg:  a close up in a [UNK] <end>
# 10995775.jpg:  a man taking a swing champagne paint [UNK] and unique door [UNK] [UNK] up at an distance with a pink fixes wine and some traffic and a man in an office. <end>
# 11003587.jpg:  an looking in a red tank with a [UNK] <end>
# 11003818.jpg:  a teddy bear holds up by a suit and posing near each other <end>
# 11005307.jpg:  white standing beagle cow <end>
# 11005332.jpg:  a collage of a young man takes a microphone in tennis uniform <end>
# 11008716.jpg:  a person poses <end>
# 11016258.jpg:  a photo could [UNK] into a fence <end>
# 11018937.jpg:  a close up shows a [UNK] various oddly hair. <end>
# 11019472.jpg:  a public man seated at his arm letting her french stacks of a [UNK] <end>
# 11023576.jpg:  a collage of a man in a camera at a [UNK] briefcase too <end>
# 11023743.jpg:  a close up school in a blender limb of a red is covering beard standing next to an apple suit. <end>
# 11026080.jpg:  the large brown bears are riding on the air with many toppings. <end>
# 11026691.jpg:  a man is both [UNK] [UNK] winning torches and making the toothbrush. <end>
# 11027372.jpg:  a couple turns with a [UNK] in front of a frame. <end>
# 11028832.jpg:  the men talking for the end while an image lays on his neck. <end>
# 11030363.jpg:  a big dog with two dogs. <end>
# 11030741.jpg:  an older man next to his head to take something into a glass while the young man wearing a camera <end>
# 11030795.jpg:  a bicyclist in doorway. <end>
# 11032056.jpg:  a little boys sits in his face. <end>
# 11033697.jpg:  a black and white cat wrapped for striped tie. <end>
# 11033868.jpg:  a man that has two teeth. <end>
# 11035215.jpg:  a close up of skiers eating a flag garage. <end>
# 11035292.jpg:  the camera. <end>
# 11038382.jpg:  a woman is not hold hands into the side of a [UNK] <end>
# 11041995.jpg:  a couple of guys are shown showing an open camera [UNK] <end>
# 11042815.jpg:  a man wearing a man with a tie preparing a flag in a conference room. <end>
# 11062219.jpg:  an [UNK] is [UNK] with row of a toy looking from it. <end>
# 11062632.jpg:  a [UNK] [UNK] a [UNK] [UNK] and it's poster wears a drinks <end>
# 11068549.jpg:  a [UNK] picture of a skull showing a watch himself next to his neck. <end>
# 11072969.jpg:  a top truck has its do not enter sign at an apple and a telephone and a [UNK] on them <end>
# 11074695.jpg:  a person is juggling while a [UNK] <end>
# 11075371.jpg:  a [UNK] glasses and a glass exposed [UNK] <end>
# 11075514.jpg:  a boy with a [UNK] <end>
# 11081539.jpg:  a man with a picture. <end>
# 11087636.jpg:  two other household goods all [UNK] <end>
# 11089234.jpg:  a black and white looking camera with graffiti [UNK] to it <end>
# 11090181.jpg:  a [UNK] dark a [UNK] in a suit on. <end>
# 11090670.jpg:  an old orange photo taken into the flooring. <end>
# 11091837.jpg:  a women standing on his smart left hand. <end>
# 11092152.jpg:  a plate of a [UNK] beside a [UNK] a spoon blows in a book <end>
# 11092495.jpg:  the reflection of a display of a close up of a [UNK] are shown [UNK] [UNK] <end>
# 11093800.jpg:  a man holding a woman in a hot dog behind it. <end>
# 11100935.jpg:  a series of a [UNK] blue display of colored shapes of a [UNK] [UNK] space is advertising piled up by the green warehouse <end>
# 11102529.jpg:  a speaker that is giving a neck [UNK] in a white plastic room. <end>
# 11106388.jpg:  a collage of two men in a long top of his skis <end>
# 11115397.jpg:  a young child is on a game. <end>
# 11115921.jpg:  a lady standing next to an old [UNK] <end>
# 11117293.jpg:  a texting in an open refrigerator. <end>
# 11125235.jpg:  a man eating a large t-shirt [UNK] the top <end>
# 11125604.jpg:  a man in an outside of kind of a jacket holding a suit, jacket leaning against a display with a bench. <end>
# 11125830.jpg:  a man and a smart phone and glove. <end>
# 11126228.jpg:  a man holding a wall. <end>
# 11135513.jpg:  a girl getting ready to reach to her doorway frame. <end>
# 11139737.jpg:  a man in the microphone. <end>
# 11140649.jpg:  a man posing with red hat warning [UNK] a sunglasses, and a baseball bat <end>
# 11140876.jpg:  a young boy with a toothbrush. <end>
# 11141907.jpg:  a man is dressed up a [UNK] his head in a building. <end>
# 11147790.jpg:  one men watch. <end>
# 11147930.jpg:  a black and a collage of a selfie of a cup of cell phones in the background. <end>
# 11148198.jpg:  a cat in grey shoes. <end>
# 11150581.jpg:  a couple of a man and a bow tie, and tie, and ties <end>
# 11154171.jpg:  a woman holding a [UNK] <end>
# 11154868.jpg:  a electronic [UNK] style [UNK] picture to my torches with a blue cup. <end>
# 11156812.jpg:  a man giving his [UNK] a mirror with his bat outside of his [UNK] with a glove with his glove while on his cell phone <end>
# 11159393.jpg:  a woman looking over a fence saying a large dog standing on it <end>
# 11160982.jpg:  a [UNK] [UNK] another man with a book shelf with a picture. <end>
# 11164716.jpg:  a man with a [UNK] <end>
# 11166154.jpg:  a man hold a photo shows a [UNK] in the background of a luggage <end>
# 11167382.jpg:  a photograph of a dog from unloading the [UNK] <end>
# 11173175.jpg:  a dog bending around a car. <end>
# 11176996.jpg:  a [UNK] dog peering up. <end>
# 11178147.jpg:  a non hats <end>
# 11179541.jpg:  a glass glasses in a double camera <end>
# 11185700.jpg:  the camera posing in the background. <end>
# 11189865.jpg:  a man with his male cap standing inside of a ramp while he has a man poses while he is displaying the air is eating a black shirt and a bow sunglasses, and a bicycle his lap. <end>
# 11192226.jpg:  a man and a shirt as a camera with a hot dog, <end>
# 11192682.jpg:  a collage of a young man with a photo a [UNK] with looking on. <end>
# 11192728.jpg:  a man is holding a glass <end>
# 11195707.jpg:  an old male in bar and an adult <end>
# 11197902.jpg:  a man in a hallway <end>
# 11209336.jpg:  man in some pink shirt in his teeth. <end>
# 11212027.jpg:  a one [UNK] and a suit and a building. <end>
# 11212201.jpg:  a man in a dishwasher <end>
# 11219996.jpg:  a couple stands next to each other. <end>
# 11223806.jpg:  a man with his [UNK] <end>
# 11225805.jpg:  a couple of a then and white ear art on his bow of a tie pose for a photo. <end>
# 11225856.jpg:  a man in black clothing sitting on a suit. <end>
# 11227148.jpg:  a dog outside a cell phones in it. <end>
# 11228134.jpg:  the camera giving his contents a catcher. <end>
# 11231744.jpg:  a very cute looking looking cat wearing a bowler hat sitting inside a display. <end>
# 11232655.jpg:  a top of a basket other items. <end>
# 11233140.jpg:  a fuzzy animal looks up in a grey outfits looking though a suit elephant wears a cow. <end>
# 11233323.jpg:  an image of a well placed where food in a [UNK] into his ear with a view of a pizza in an enclosure with some green plastic clothes. <end>
# 11233414.jpg:  a close up of a blurry of a close up of a toaster perched alone next to a glass. <end>
# 11233505.jpg:  a man wearing a [UNK] <end>
# 11233570.jpg:  a close up of a bald old photo of professionally sitting next to a [UNK] <end>
# 11234298.jpg:  a person sticking up. <end>
# 11236103.jpg:  a small old lady standing next to other ties <end>
# 11238564.jpg:  a man is dressed in a top <end>
# 11238586.jpg:  a closeup of a photo of glasses and glasses of a small setting. <end>
# 11242145.jpg:  three close up at a mans teeth. <end>
# 11247812.jpg:  at a fake [UNK] <end>
# 11262038.jpg:  a cat looking drinks a basket basket standing next to a big basket with various glow in a table. <end>
# 11262464.jpg:  a large group of different colored [UNK] with a yellow trunks is making cookies <end>
# 11267902.jpg:  the two men and a [UNK] and a [UNK] a suit, vest next to a tie. <end>
# 11269967.jpg:  a man on a tank <end>
# 11270159.jpg:  a dog and its door and its tongue out. <end>
# 11271971.jpg:  a man in a green ear [UNK] home unique [UNK] meat in a tie and a top suit, <end>
# 11276919.jpg:  a man looking up a life day. <end>
# 11278758.jpg:  a blurry photo of a blurry photo and a [UNK] a [UNK] and a microphone on. <end>
# 11278862.jpg:  a series of a picture of her [UNK] mostly black jacket for an [UNK] looking at the other. <end>
# 11280528.jpg:  a poster of sheep. <end>
# 11284685.jpg:  a man in the camera. <end>
# 11284874.jpg:  a man in a bow tie eating his neck tie at his [UNK] and a green tie. <end>
# 11297090.jpg:  a collage of a man and a necktie. <end>
# 11298490.jpg:  an image in a park park holding onto the process of a [UNK] long tie eating while holding a camera catcher. <end>
# 11311827.jpg:  a man sits beside a mantle on his bicycle on a bench while an tomato. <end>
# 11318136.jpg:  a group of people are watching a wine and art and one and the three persons words take them. <end>
# 11320777.jpg:  man in the middle of a [UNK] <end>
# 11323668.jpg:  a man looking at a wall. <end>
# 11340405.jpg:  a closeup of a there are looking cows standing next to a display in a wood bag. <end>
# 11348638.jpg:  seven young man has an open in a double mirror. <end>
# 11353053.jpg:  a striped two brown colored and white fixes a glass sheep and two wooden pattern. <end>
# 11355934.jpg:  the person holding a trick. <end>
# 11357464.jpg:  a close up of a [UNK] smiling sign while a [UNK] <end>
# 11363812.jpg:  a close up of a man in a black <end>
# 11368133.jpg:  a old man holding in a home. <end>
# 11368575.jpg:  a close up of himself as a variety of a [UNK] up wearing a microphone. <end>
# 11368710.jpg:  a skull and a tie [UNK] and a picture of his man that is treat. <end>
# 11371547.jpg:  a victory [UNK] and other items. <end>
# 11371864.jpg:  a young boy is in the other wearing a chair next to a whole fake tray. <end>
# 11372738.jpg:  a woman covered [UNK] while two men start a [UNK] <end>
# 11379425.jpg:  a [UNK] into a glass peering onto try and his [UNK] a suit has onto a microphone. <end>
# 11379528.jpg:  a close up of four [UNK] into a [UNK] <end>
# 11380560.jpg:  a picture of a [UNK] [UNK] directions. <end>
# 11385269.jpg:  a selfie of their eyes. <end>
# 11385620.jpg:  two men standing next to a fence that if his head. <end>
# 11386712.jpg:  a close up a couple [UNK] items in a display in a moving beside a couple in a bar with three different kind of pies. <end>
# 11390095.jpg:  a close up a demonstration holding a phone for a flip tie. <end>
# 11398559.jpg:  the glass table full of ale beside a [UNK] <end>
# 11401379.jpg:  a man in a clothes [UNK] scarf also has been adjusts his phone. <end>
# 11401507.jpg:  small oriental hangs champagne under a suit. <end>
# 11407094.jpg:  a man giving the top <end>
# 11412723.jpg:  a man reading a suit, suit and a suit tank top a book against a window. <end>
# 11413669.jpg:  pink costume in treats. <end>
# 11414841.jpg:  a collage of self for a tie <end>
# 11417736.jpg:  a dark blue boat is standing on the dirt. <end>
# 11429067.jpg:  a man with a small tie <end>
# 11430474.jpg:  a blurry bald image of a wine glass. <end>
# 11432556.jpg:  a large black looking cat is posing. <end>
# 11437116.jpg:  a man in a museum <end>
# 11447566.jpg:  a man with a tuxedo and a bowler hat has it's reflection of the camera while he space. <end>
# 11447725.jpg:  a couple of a black and white and white and a large dog in a tray. <end>
# 11448510.jpg:  a woman standing by a glass room with a long lot of a bird behind a dog with than them. <end>
# 11449388.jpg:  a great [UNK] in a baking torches <end>
# 11452738.jpg:  a woman's fixes most of tennis artwork. <end>
# 11462876.jpg:  an old [UNK] sits on a phone <end>
# 11472747.jpg:  a man holding a speech. <end>
# 11476878.jpg:  a [UNK] lights and sniffing on. <end>
# 11480742.jpg:  a young man holding a beer. <end>
# 11483121.jpg:  a glass in an outside in a glass table set for the store. <end>
# 11483153.jpg:  a group of men standing beside a lecture to cross [UNK] <end>
# 11488530.jpg:  a woman holding a sweater. <end>
# 11490469.jpg:  there is figure next to warehouse <end>
# 11494046.jpg:  a decorated blue plastic fancy white umbrellas on display window with long desert in a store. <end>
# 11500076.jpg:  a few men are sitting next to her hands. <end>
# 11501214.jpg:  a man that is pointing into a glass. <end>
# 11504640.jpg:  a picture of a lady wearing an open refrigerator. <end>
# 11504645.jpg:  a woman in black jacket eating a suit and prepare a historic office with a [UNK] [UNK] <end>
# 11504678.jpg:  a man with a tablet so another outfit reading notes for a container and a [UNK] something. <end>
# 11517197.jpg:  a young men in a seat of two other on. <end>
# 11519508.jpg:  an older man standing next to each other. <end>
# 11521456.jpg:  a [UNK] of a tie sitting near a [UNK] <end>
# 11529365.jpg:  a collage of small smiling and a man on a big picture. <end>
# 11529444.jpg:  two pictures of two women by her wedding. <end>
# 11530290.jpg:  a woman at a room. <end>
# 11537151.jpg:  a couple of four hanging from the wind. <end>
# 11537945.jpg:  man during a red and a tennis as if it tie turning <end>
# 11544423.jpg:  a collage of pictures of a short smiling lunch for an apple. <end>
# 11547879.jpg:  a man featuring the women dressed next to a book <end>
# 11551985.jpg:  a sun types of a basket in their mouth and wearing a long [UNK] <end>
# 11552324.jpg:  a woman is making a split [UNK] one hand <end>
# 11552585.jpg:  a young lady is playing while another <end>
# 11558975.jpg:  a [UNK] lots of a [UNK] two different bottles and a picture while another model behind a counter with two cabinets <end>
# 11559300.jpg:  a plastic pointing up some kind of a variety of different [UNK] st. [UNK] items relaxing in a store. <end>
# 11562383.jpg:  one is peeling a cup <end>
# 11567885.jpg:  a man holding a call in front of a [UNK] <end>
# 11575405.jpg:  a male man with a black [UNK] [UNK] <end>
# 11581948.jpg:  a woman's neck. <end>
# 11586399.jpg:  three men in front of a museum him each other with his black shirts mounted to start cones. <end>
# 11593331.jpg:  a woman holds words on. <end>
# 11599707.jpg:  a [UNK] woman getting ready to a storage dress military [UNK] goods on an arena <end>
# 11603855.jpg:  a collage of a [UNK] in the distance. <end>
# 11603906.jpg:  a man in a suit touching a white suit. <end>
# 11611365.jpg:  a man eating professionally <end>
# 11611376.jpg:  a worn hats and a sign <end>
# 11620950.jpg:  two men shelf looking into their clothes course. <end>
# 11622317.jpg:  a woman [UNK] juggling a table with two cellphones while wearing a [UNK] computers. <end>
# 11625331.jpg:  a close up of a toilet in a room next to another man. <end>
# 11633012.jpg:  a man in leather phones. <end>
# 11643251.jpg:  a man taking a selfie in the shop <end>
# 11644933.jpg:  the [UNK] <end>
# 11649326.jpg:  a picture of a blue [UNK] of bananas. <end>
# 11649534.jpg:  a man in the other next to each other. <end>
# 11650317.jpg:  a couple of many different architectural display bottles. <end>
# 11650764.jpg:  a man holding up the rest room with a top <end>
# 11651719.jpg:  a man in a suit handle. <end>
# 11661264.jpg:  three individual shopping kind of a cup with a beverage spot. <end>
# 11664665.jpg:  three [UNK] in a black tops, on top of a learning how to play a coat <end>
# 11666932.jpg:  a long mother and a worn with a bear sitting on a large, old [UNK] underneath a rock near some green jacket and a [UNK] while [UNK] rest in a moss on a cap foraging in a hammock. <end>
# 11674136.jpg:  a man pointing for his neck. <end>
# 11674769.jpg:  a person are eating a [UNK] <end>
# 11676507.jpg:  a couple of a dog are standing beside a dog in a field <end>
# 11677778.jpg:  a decorated with a blue many ingredients in a rail with four [UNK] [UNK] of [UNK] a no dogs. <end>
# 11679511.jpg:  a dog that has a dog and a post. <end>
# 11684142.jpg:  a police to see a baby playing an amusement day. <end>
# 11686506.jpg:  a collage of photos of bottles of ear of ties with a beer and a couple of fish magazine bottle. <end>
# 11686564.jpg:  a small giraffe has just laying around a bag and looking up alone. <end>
# 11686849.jpg:  a close up at a [UNK] next to a crowd. <end>
# 11690717.jpg:  a parent and a boy on it. <end>
# 11691407.jpg:  a close up of three next to a man and a [UNK] hat on it. <end>
# 11692056.jpg:  a close up of dog [UNK] in a museum. <end>
# 11694708.jpg:  a man looking women standing beside her. <end>
# 11695717.jpg:  a close to waiting for the other political uniform if another man in his teeth. <end>
# 11697164.jpg:  a [UNK] mostly [UNK] a hanging on it <end>
# 11697215.jpg:  a tall kitchen pose for the u.s. and a one [UNK] and a one pours each other. <end>
# 11698689.jpg:  a man in a bowler hat. <end>
# 11698734.jpg:  a man eating a high up to her. <end>
# 11700701.jpg:  a bar person's teeth with a corner in a shelf. <end>
# 11703983.jpg:  a man in a museum exhibit smiling. <end>
# 11723606.jpg:  a brown and a [UNK] a man and a smiling at a black and a [UNK] <end>
# 11723663.jpg:  a couple of a close up of a pet with a small trucks covered beside a couch. <end>
# 11728729.jpg:  a cozy looking at a large [UNK] shelf. <end>
# 11728753.jpg:  a japanese teams going over the room as it <end>
# 11729625.jpg:  a male in a camera from his ice tie sticking his glass of a [UNK] <end>
# 11740525.jpg:  a [UNK] [UNK] to it <end>
# 11742544.jpg:  a man sitting around his cupboard <end>
# 11743647.jpg:  a couple of sheep behind a decorated with his [UNK] as another man on the directions. <end>
# 11747628.jpg:  a thin [UNK] [UNK] are [UNK] in. <end>
# 11750407.jpg:  a man and a dog are looking at a picnic in a match. <end>
# 11751989.jpg:  a unique [UNK] in a microphone. <end>
# 11755961.jpg:  a dog is eating a camera <end>
# 11758099.jpg:  a man eats a dog sitting underneath an iron fence. <end>
# 11767591.jpg:  a large, animal peering into the bow hanging from an air while well making a woven mirror. <end>
# 11768722.jpg:  a second dog and a worker can with a cow. <end>
# 11769104.jpg:  a close up for a photo [UNK] it. <end>
# 11774804.jpg:  two young lady is dressed up a tennis racquet. <end>
# 11776255.jpg:  a lady standing on top of three other's ear beyond a display. <end>
# 11784319.jpg:  a wooden exhibit of a drawing of a dog laying next to each other. <end>
# 11785279.jpg:  a man with a red clothing either rooms. <end>
# 11791220.jpg:  the toddler man sits with four books in front of a [UNK] <end>
# 11797865.jpg:  a little male railway dressed for us glasses and looking meat, and a [UNK] a victory [UNK] hat. <end>
# 11798815.jpg:  a dog with a machine <end>
# 11799064.jpg:  an older man is juggling a stage. <end>
# 11806243.jpg:  a poster of a side by a museum from his shirt and bow ties <end>
# 11813370.jpg:  a man wearing a museum cabinets. <end>
# 11823051.jpg:  a couple of a black and white photo of a [UNK] in a conference room. <end>
# 11824298.jpg:  a [UNK] [UNK] <end>
# 11826901.jpg:  two pictures of two different a number of white and white and white lamb including their all peeking into a brush. <end>
# 11829234.jpg:  a young boy in white dress all in a uniform <end>
# 11838615.jpg:  a white and a [UNK] and a small puppy with a giraffe looking at the camera. <end>
# 11849099.jpg:  the man is standing at home. <end>
# 11867336.jpg:  a large white picture of a gathering plastic [UNK] a balcony is decorated with an assortment of the old directions. <end>
# 11870785.jpg:  a man standing next to it. <end>
# 11871321.jpg:  a skull sitting graduation tie is lamps <end>
# 11871367.jpg:  a man wearing a fence <end>
# 11872936.jpg:  a thin bull has icing <end>
# 11877762.jpg:  a woman are on their pen on their computers <end>
# 11878414.jpg:  a man smiling professionally <end>
# 11879472.jpg:  a man holding glasses and a pink tie <end>
# 11881716.jpg:  a [UNK] through blue cabinets and a forest that is steeple. <end>
# 11883612.jpg:  the man with three skills on a driveway. <end>
# 11883633.jpg:  a dog in a plane. <end>
# 11886240.jpg:  a collage of a skull in his [UNK] <end>
# 11886252.jpg:  a little girl with a [UNK] over a [UNK] [UNK] <end>
# 11891046.jpg:  a small woman staring up and one holding the petting an [UNK] around <end>
# 11896354.jpg:  two men in a book <end>
# 11896373.jpg:  the other guys posing with an old [UNK] [UNK] book <end>
# 11896464.jpg:  a man and a bow roses. <end>
# 11896475.jpg:  a man sitting in a bar in a [UNK] <end>
# 11896524.jpg:  three men sitting in front of a factory. <end>
# 11899327.jpg:  a man dressed in a red tie and a [UNK] <end>
# 11899999.jpg:  a blue fire hydrant on a court. <end>
# 11904887.jpg:  a man sitting holding a small chairs with a hat british [UNK] behind. <end>
# 11905186.jpg:  a man is at milk with a wall <end>
# 11905766.jpg:  a man holding a top of an animal. <end>
# 11908799.jpg:  someone in black and a trick <end>
# 11912346.jpg:  a man on a steps <end>
# 11921159.jpg:  this man that are on the bottom of a wall next to a book [UNK] <end>
# 11929717.jpg:  a man posing for a high in a runway with his own [UNK] next to [UNK] side while holding a magazine surrounded by rocks. <end>
# 11931392.jpg:  a number of several [UNK] are dressed through a display at tv. <end>
# 11935139.jpg:  a man sitting down using a bottle of a side by a [UNK] in a train <end>
# 11935501.jpg:  a person looking into the top taken. <end>
# 11935721.jpg:  a close up of a tall a close up of a close up photo of a gray and white photo of a [UNK] [UNK] of the camera. <end>
# 11936491.jpg:  two large image. is shown has pieces of a [UNK] <end>
# 11937464.jpg:  a man wearing a attached to a suit posing next to the camera, costume while leaning against a high tie. <end>
# 11948157.jpg:  a boy that is hanging and other torches [UNK] [UNK] <end>
# 11952700.jpg:  a silver man lying in a wine [UNK] [UNK] [UNK] in a blue chair. <end>
# 11955339.jpg:  a man giving a tie next to a top of a neck tie. <end>
# 11962116.jpg:  a man wearing a tie lane. <end>
# 11962180.jpg:  a man in a [UNK] <end>
# 11966452.jpg:  a guy laying next to his bike. <end>
# 11967309.jpg:  a man in a glass. <end>
# 11969652.jpg:  the man in his luggage and some kind of the camera. <end>
# 11972560.jpg:  a man with a jump in his shoulders outside of a black surface. <end>
# 11974042.jpg:  a display very small sheep construction shapes to [UNK] <end>
# 11978138.jpg:  a [UNK] close up close up into a yellow suit, glove <end>
# 11993353.jpg:  a looking sink sitting beside it <end>
# 11999399.jpg:  a top hat on stage. <end>
# 11999443.jpg:  an image of a [UNK] up a hat. <end>
# 12008054.jpg:  multiple photo of a glass cup holder next to a vase wearing a purse <end>
# 12010294.jpg:  a glass of man holding several different directions. <end>
# 12015479.jpg:  a man holding a whole clothed using his teeth. <end>
# 12018292.jpg:  a winning foreign types of one of a basket with beard and painting a green <end>
# 12019014.jpg:  a close up of a dog [UNK] dog behind it. <end>
# 12019259.jpg:  a woman with a photo of the dog <end>
# 12019342.jpg:  a man dressed up a brown plastic chicken while his tablet <end>
# 12019886.jpg:  a couple gathers next to a victory fan. <end>
# 12020340.jpg:  a collage of a man on a bathroom. <end>
# 12022152.jpg:  man smiling wine stall. <end>
# 12024909.jpg:  a [UNK] in a suit, jacket and a tie <end>
# 12028602.jpg:  a boy reading a neck after another a glass. <end>
# 12028633.jpg:  a man posing in a picture. <end>
# 12029153.jpg:  a long dog with a bow his baby leg up to his face. <end>
# 12035990.jpg:  a counter with lots of books <end>
# 12041276.jpg:  a man is photos of a book state of a tie gazing at a living room. <end>
# 12045073.jpg:  a [UNK] side by some wine look. <end>
# 12048195.jpg:  a close up of a round member from a close up of a member of a woman eating gazing at a green dress with a great [UNK] to the camera. <end>
# 12059984.jpg:  a [UNK] of it's other near a [UNK] some kind of a [UNK] back. <end>
# 12062836.jpg:  a small ripe female frames of four three photos of young lady holds a basket while dressed in a case. <end>
# 12076073.jpg:  a tall tall black and white on a building <end>
# 12084995.jpg:  a man is photos is drinking sticking [UNK] <end>
# 12086488.jpg:  a water [UNK] and [UNK] [UNK] <end>
# 12088923.jpg:  a colorful bird is standing next to a glove. <end>
# 12090698.jpg:  a man wearing an ear of a suit. <end>
# 12091214.jpg:  a male smiling tuxedo and a camera [UNK] <end>
# 12104403.jpg:  a hot asian women in a [UNK] <end>
# 12119037.jpg:  a male in a top hat post. <end>
# 12149915.jpg:  lots of three different types of people standing next to a [UNK] into a partly cloudy sky. <end>
# 12155072.jpg:  a furry dog and a pink trunks stands on a [UNK] a pink furniture. <end>
# 12170628.jpg:  a boy that eats green tank from the lake next to each other. <end>
# 12181950.jpg:  a man was photos and white crocheted small people. <end>
# 12210751.jpg:  a man takes a collage of wine [UNK] in costume to see a [UNK] [UNK] nail used an easy carry torches and a rack full photo is singing into the top of a glass table behind each other. <end>
# 12219065.jpg:  several colors of boots at a [UNK] <end>
# 12223641.jpg:  a cyclist [UNK] [UNK] giving a [UNK] hair [UNK] microphone and tie and a old black and a torches and a [UNK] at the edge of his neck. <end>
# 12224603.jpg:  the old old and white garbage display in a basket <end>
# 12229015.jpg:  the old woman sitting down at his state of a watch him <end>
# 12237139.jpg:  a [UNK] sits on his bike with different umbrellas are in a white van <end>
# 12242160.jpg:  a young people dress. <end>
# 12250585.jpg:  a collage of a collage of wine <end>
# 12250747.jpg:  a collage of onlookers covered behind his back of a ottoman <end>
# 12254537.jpg:  a [UNK] bus on a bed. <end>
# 12255399.jpg:  two kids with some sheep. <end>
# 12255497.jpg:  two little young giraffes walking around their coach. <end>
# 12255673.jpg:  two people are playing soccer. <end>
# 12270286.jpg:  a black and white photo of a tie and a microphone. <end>
# 12270966.jpg:  a blurry image of a tie and a tie and a neck tie. <end>
# 12271226.jpg:  a picture of a large tie holding a shirt and some kind of one black ears [UNK] <end>
# 12271228.jpg:  a woman holding a shirt <end>
# 12272214.jpg:  a young older women in a tie dye tie while a tie <end>
# 12272666.jpg:  a pair of white photo of a pair of elderly three siamese pictures on a [UNK] <end>
# 12273664.jpg:  a old rear photo of a red tie and tie and a black colors are in a conference suit and the camera <end>
# 12273771.jpg:  a close up a sticking up to one of an iron uniform waving with a selfie in the left [UNK] <end>
# 12274350.jpg:  a couple [UNK] man in an [UNK] <end>
# 12276235.jpg:  a young man with a [UNK] blue [UNK] <end>
# 12276574.jpg:  a male with a tie and a green shirt and blue photo <end>
# 12276661.jpg:  a pretty young boy is wearing a tie <end>
# 12276685.jpg:  a young young headed young male is a tie and tie in a plaid dress. <end>
# 12291165.jpg:  an young man with a picture <end>
# 12292784.jpg:  a [UNK] beat next to two large [UNK] <end>
# 12292883.jpg:  the attractive black man wearing a hat leaning against a rubber [UNK] next to a beard standing next to a banana. <end>
# 12294292.jpg:  a young boy in a wire zoo clothes <end>
# 12295274.jpg:  a black wall in their boots up. <end>
# 12296259.jpg:  a man giving some kind of a microphone. <end>
# 12297718.jpg:  a closeup of a close up from the backdrop of the two others. <end>
# 12301610.jpg:  a man holding a picture. <end>
# 12304262.jpg:  a collage of a young man talking on top of an office object. <end>
# 12307164.jpg:  a man with a hotdog with one and standing by the other <end>
# 12319463.jpg:  a man and a [UNK] a number of a pickle using a [UNK] to be covered the same lights <end>
# 12331797.jpg:  a man in glasses and two sharpie torches in front of a [UNK] sign sits behind them. <end>
# 12332062.jpg:  a [UNK] looking on. <end>
# 12346850.jpg:  a man looking into a hold an overhead tie and a [UNK] tie down <end>
# 12347401.jpg:  a beautiful woman and looking at their lap <end>
# 12354139.jpg:  a man with each other. <end>
# 12358758.jpg:  a man is wearing an apartment bar. <end>
# 12359108.jpg:  a small bird and a person <end>
# 12364842.jpg:  a small girl with a teddy bear <end>
# 12367593.jpg:  a picture of women standing beside each other after on a book. <end>
# 12368023.jpg:  people inside a banquet [UNK] in a factory. <end>
# 12382543.jpg:  a woman touches her purse. <end>
# 12387572.jpg:  a couple of a man with a sweater is bending around in black suit. <end>
# 12389909.jpg:  a man eating a glass as he [UNK] <end>
# 12400872.jpg:  a contents of a small nintendo wii is not is tagging not writing on a wall. <end>
# 12403035.jpg:  a man with a telephone jacket holding up while he can to a funny [UNK] <end>
# 12406215.jpg:  a woman with different [UNK] [UNK] <end>
# 12419682.jpg:  a man in a table <end>
# 12422697.jpg:  a [UNK] in a yellow toilet dressed in a [UNK] dress decorated with a glass wooden items <end>
# 12426163.jpg:  a couple of a woman in a tennis net while in black tops, a stroller in a plaid shirt and an older man. <end>
# 12431040.jpg:  this is a tie and a tie eating a uniform. <end>
# 12437372.jpg:  an indoor setting of a tunnel and a bakery. <end>

# %%
import glob
#image_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ab/TensorFlow_logo.svg/1200px-TensorFlow_logo.svg.png'
#image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)
#print(image_path)
path = '/content/drive/MyDrive/meme_df/meme-generator-dataset/memegenimages/'
for filename in glob.glob(os.path.join(path, '*.jpg')):
   with open(os.path.join(os.getcwd(), filename), 'r') as f:
       result, attention_plot = evaluate(os.path.join(os.getcwd(), filename))
       print(filename[-12:]+': ' , ' '.join(result))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8d9079cbce99> in <module>()
#       4 #print(image_path)
#       5 path = '/content/drive/MyDrive/meme_df/meme-generator-dataset/memegenimages/'
# ----> 6 for filename in glob.glob(os.path.join(path, '*.jpg')):
#       7    with open(os.path.join(os.getcwd(), filename), 'r') as f:
#       8        result, attention_plot = evaluate(os.path.join(os.getcwd(), filename))
#
# NameError: name 'os' is not defined
